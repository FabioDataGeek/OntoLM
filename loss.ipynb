# %%
import pickle as pkl
import json
import matplotlib.pyplot as plt

# %%
with open('/usrvol/resultados/categórico correcto 17-11-2023/loss_lr.json', 'r') as f:
    data = json.load(f)

# %%
iterator = None
data_per_epoch = []
for i in range(len(data)):
    epoch = data[i]['epoch']
    if iterator != epoch:
        iterator = epoch
        data_per_epoch.append([])
    data_per_epoch[-1].append(data[i]['loss'])

# %%
len(data_per_epoch[10])
# Out:
# 89

# %%
data_per_epoch[0][-1]
# Out:
# 0.01536194384098053

# %%
for i in range(len(data_per_epoch[88:])):
    plt.plot(data_per_epoch[i], label='epoch {}'.format(i))

plt.legend()
